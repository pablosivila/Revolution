# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!

# %% [markdown]
# In this exercise, we  will generate random numbers from the continuous disributions we learned in the lesson. There are two ways to generate random numbers:
#
# 1. Using the numpy library
# 1. using the Scipy library
#
# Use either or both of the lbraries in this exercise.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Uniform Distribution
#
# To generate uniform random numbers between any two given values using scipy, we can either use the following code or the code that we have
# discussed in class:

# %%
from scipy.stats import uniform
x = uniform.rvs(size=10)
a = 2
b = 3
randoms  = a + (b-a)*x
print(randoms)
# Out:
# [2.17811126 2.86946074 2.45653468 2.09879153 2.81245189 2.56392912
#  2.76085931 2.56031368 2.49667215 2.21983824]

# %%
len(x)
# Out:
# 10

# %%
type(x)
# Out:
# numpy.ndarray

# %%
print(x.max())
print(x.min())
# Out:
# 0.8694607352498713
# 0.0987915293593119

# %%
print(x)
# Out:
# [0.17811126 0.86946074 0.45653468 0.09879153 0.81245189 0.56392912
#  0.76085931 0.56031368 0.49667215 0.21983824]

# %% [markdown]
# **Your task:**
#
# 1. Based on the code above, write a function that generates uniformly distributed random numbers. There are several requirements for your function:
#     * It should accept 3 parameters:
#         * `bottom` - the lower boundary of the generated numbers
#         * `ceiling` - the upper boundary of the generated numbers
#         * `count` - how many numbers to generate
#     * It should return an array of uniformly distributed random numbers
#
# 1. Call your function with 2 sets of params below:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 1. Plot the uniform distributions generated above using histograms, where x axis is the value and y axis is the count. Let the histogram's number of bins be 10.
#
# Your output should look like below:
#
# ![uniform distribution](ud.png)

# %%
# your code here
bottom1 = 10 #lowest value
ceiling1 = 15 #highest value
count1 = 100 #number of elements

# %%
bottom2 = 10 #Lowest Value
ceiling2 = 60 #highest value
count2 = 1000 #number of elements

# %%
set1 = np.random.uniform(bottom1, ceiling1, count1)

# %%
set2 = np.random.uniform(bottom2, ceiling2, count2)

# %%
set1
# Out:
# array([10.57135679, 12.994634  , 10.15128867, 14.71410977, 11.25290366,
#        11.14738259, 13.09843157, 13.71407155, 10.79829068, 11.57218268,
#        13.87305748, 11.16623597, 10.57695165, 13.83268697, 13.30358541,
#        10.51672149, 10.30051204, 10.32227566, 14.43011503, 12.714107  ,
#        10.7237268 , 13.50431001, 11.74416071, 14.59787727, 14.99094896,
#        10.4113798 , 10.90628211, 11.2777979 , 13.41194706, 11.04908074,
#        11.34334742, 12.57337087, 13.79124314, 10.2381709 , 14.90384904,
#        14.27436238, 11.28291731, 10.88031925, 12.22148153, 12.95108558,
#        12.6078575 , 11.95470131, 13.06719115, 13.11323659, 10.12905684,
#        13.75065148, 13.37424327, 11.01853214, 12.55202836, 10.37339262,
#        12.22070085, 13.63748145, 12.08765599, 11.11133882, 14.68651452,
#        10.9083152 , 12.49838414, 10.72819276, 13.47299474, 13.38756845,
#        14.17438346, 10.82869557, 10.07010152, 11.72039922, 10.63285432,
#        13.2725779 , 11.24549327, 14.06651816, 11.66358681, 12.91613538,
#        11.52400043, 13.69351628, 14.08261611, 13.74921431, 14.23407952,
#        10.12103821, 14.86437471, 12.03952336, 14.11299758, 10.00732788,
#        58.64122228, 26.57210554, 31.92602421, 17.03292313, 51.62203851,
#        43.39314244, 55.90213908, 55.21280508, 50.72089449, 48.68787047,
#        15.05746215, 22.77708138, 57.97750402, 22.85613709, 26.50571428,
#        47.52107969, 32.10253159, 39.86724283, 52.21556823, 45.56460715,
#        21.39305298, 45.21592957, 44.88637132, 53.98535291, 12.43520678,
#        51.70568194, 22.34537731, 13.52922708, 21.68950859, 23.23784441,
#        44.27597548, 10.9487151 , 34.4502929 , 31.50155445, 24.57275247,
#        29.54922748, 38.07630808, 25.68255944, 22.53261186, 27.40570544,
#        36.60757085, 15.3253428 , 44.9449893 , 58.72160814, 59.43258667,
#        51.95785704, 33.35778385, 43.28095156, 22.48208702, 23.67279737,
#        43.76480748, 35.25468308, 52.3487577 , 11.24798055, 40.82012093,
#        22.27146701, 11.79496198, 42.78052519, 43.59992194, 52.04710861,
#        34.88645649, 49.54796719, 11.01858373, 22.80548699, 42.61566027,
#        41.43989422, 56.5968229 , 32.9745671 , 40.79849149, 22.3228049 ,
#        42.86903701, 29.37598619, 38.44568177, 20.68378128, 27.03391405,
#        20.60889736, 17.55240198, 42.86852285, 25.90313424, 39.04983764,
#        58.63623305, 40.959217  , 54.43573197, 26.65618125, 59.35741256,
#        36.95635006, 33.84565724, 43.60201824, 43.86842012, 52.05219507,
#        35.76476942, 59.98497594, 50.93076975, 49.8977769 , 40.15698817,
#        54.4441527 , 26.04054849, 41.76379268, 39.30699821, 49.38014927,
#        38.24800974, 54.05611058, 56.06383499, 29.93091377, 42.04599281,
#        14.84962954, 26.07735111, 21.32481265, 29.92297531, 53.39308334,
#        57.46700648, 45.94292782, 20.80667166, 47.25433619, 16.88458427,
#        13.71778304, 20.59966671, 45.54695493, 44.03888426, 41.77137149,
#        38.02930729, 44.09728918, 22.66029261, 13.56444832, 12.19195385,
#        10.09731406, 45.43225456, 14.63391246, 30.46376501, 35.96949231,
#        40.6200368 , 40.07572277, 29.78452196, 55.86068103, 17.65023758,
#        11.72250256, 12.82143096, 37.53067547, 20.5562735 , 43.66266569,
#        59.14505888, 33.59663014, 22.79417037, 18.2175608 , 35.62289678,
#        54.54135711, 40.59114646, 34.29718522, 29.30875084, 40.60633678,
#        30.38894675, 20.13993211, 31.61280965, 18.9072039 , 45.56842725,
#        29.59593478, 12.19278222, 56.83770162, 43.90491073, 57.93755552,
#        23.13025195, 16.65379506, 29.58741026, 35.08286382, 40.99367829])

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below

fig, (chart1, chart2) = plt.subplots(1,2, sharey = True, figsize=(15,5))

# %%
chart1.hist(set1, bins = 30)
chart1.set_title('set1')

chart2.hist(set2, bins = 30)
chart2.set_title('set2')
# Out:
# Text(0.5, 1, 'set2')

# %%
fig, (chart1, chart2) = plt.subplots(1,2, sharey = True, figsize=(15,5))

chart1.hist(set1, bins = 30)
chart1.set_title('set1')

chart2.hist(set2, bins = 30)
chart2.set_title('set2')
# Out:
# Text(0.5, 1.0, 'set2')

# %% [markdown]
# ## Normal Distribution
#
# 1. In the same way in the Uniform Distribution challenge, write a function that generates normally distributed random numbers.
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 1
# 1. Generate 1,000 normally distributed numbers with the average of 10 and standard deviation of 50
# 2. Plot the distributions of the data generated.
#
# Expected output:
#
# ![normal distribution](nd.png)

# %%
# your code here
from scipy.stats import norm

func1 = np.random.normal(loc = 10, scale = 1, size = 1000)

# %%
func2 = np.random.normal(loc = 10, scale = 50, size = 1000)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer below
fig, (ax1, ax2) = plt.subplots(1,2, sharey = True)

ax1.hist(func1, bins = 50)
ax1.set_title('func1')

ax2.hist(func2, bins = 50)
ax2.set_title('func2')
# Out:
# Text(0.5, 1.0, 'func2')

# %% [markdown]
# ## Normal Distribution of Real Data
#
# In this challenge we are going to take a look the real data. We will use vehicles.csv file for this exercise

# %% [markdown]
# First import vehicles.csv.
# Then plot the histograms for the following variables:
#
# 1. Fuel Barrels/Year

# %%
# your code here
df = pd.read_csv('vehicles.csv')

# %%
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 0   Regular          19.388824        18           17            17
# 1   Regular          25.354615        13           13            13
# 2   Regular          20.600625        16           17            16
# 3   Regular          25.354615        13           13            13
# 4   Premium          20.600625        14           21            16
#
#    CO2 Emission Grams/Mile  Fuel Cost/Year
# 0               522.764706            1950
# 1               683.615385            2550
# 2               555.437500            2100
# 3               683.615385            2550
# 4               555.437500            2550

# %%
df['Fuel Barrels/Year'].hist(bins = 50)

# %%
sns.despine()

# %% [markdown]
# 2. CO2 Emission Grams/Mile

# %%
# your code here
df['CO2 Emission Grams/Mile'].hist(bins = 50)
sns.despine()

# %% [markdown]
# 3. Combined MPG

# %%
# your code here
df['Combined MPG'].hist(bins = 50)
sns.despine()

# %% [markdown]
# Which one(s) of the variables are nearly normally distributed? How do you know?

# %%
# your answer here
from scipy.stats import normaltest, skewtest

# %%
norm_test = normaltest(df['Fuel Barrels/Year']) 
norm_test
# Out:
# NormaltestResult(statistic=3216.559790182245, pvalue=0.0)

# %%
norm_test = normaltest(df['CO2 Emission Grams/Mile']) 
norm_test
# Out:
# NormaltestResult(statistic=3608.604030545311, pvalue=0.0)

# %%
norm_test = normaltest(df['Combined MPG']) 
norm_test
# Out:
# NormaltestResult(statistic=6994.459897617527, pvalue=0.0)

# %%
#Pelo pvalue de todos as colunas sereme 0.0; e ela sendo inferior a 0.05
#Todas variaveis sao consideradas normais 0,0 < 0,05

# %% [markdown]
# ## Exponential Distribution

# %% [markdown]
# 1. Using `numpy.random.exponential`, create a function that returns a list of numbers exponentially distributed with the mean of 10.
#
# 1. Use the function to generate two number sequences with the size of 1 and 100.
#
# 1. Plot the distributions as histograms with the nubmer of bins as 100.
#
# Your output should look like below:
#
# ![exponential distribution](ed.png)

# %%
# your code here
def expo_func(mean, size):
    return(np.random.exponential(mean,size))

#Correção: mean = 1 e 100 ; size = 1000

# %%
expo1 = expo_func(1, 1000)
expo2 = expo_func(100, 1000)

# %% [markdown]
# How are the two distributions different?

# %%
# your answer here
fig, (ex1, ex2) = plt.subplots(1, 2, sharey = True, figsize = (15, 5))

ex1.hist(expo1, bins = 100)
ex2.hist(expo2, bins = 100)
sns.despine()

# %% [markdown]
# ## Exponential Distribution of Real Data
#
# Suppose that the amount of time one spends in a bank is exponentially distributed with mean as 10 minutes (i.e. λ = 1/10). What is the probability that a customer will spend less than fifteen minutes in the bank?
#
# Write a code in python to solve this problem

# %%
# your answer here
# Hint: This is same as saying P(x<15)

from scipy.stats import expon

# %% [markdown]
# What is the probability that the customer will spend more than 15 minutes

# %%
# your answer here

prob_exp = expon.cdf(15, loc=10)

# %%
1 - prob_exp
# Out:
# 0.006737946999085476
